# %%
import pandas as pd

# %%
df = pd.read_csv('Aggregate_Results.csv')

# %%
df
# Out:
#          Country      Date  Volume
# 0      Venezuela  1/1/2016     1.0
# 1             US  1/1/2016    83.0
# 2          India  1/1/2016     0.0
# 3         Brazil  1/1/2016     1.0
# 4       Malaysia  1/1/2016     1.0
# ...          ...       ...     ...
# 47977  Venezuela  9/8/2019    10.0
# 47978  Venezuela  9/9/2016     1.0
# 47979  Venezuela  9/9/2017     1.0
# 47980  Venezuela  9/9/2018     0.0
# 47981  Venezuela  9/9/2019    11.0
#
# [47982 rows x 3 columns]

# %%
df['Date'] = df['Date'].apply(pd.to_datetime)

# %%
df.sort_values(by=['Date'])
# Out:
#            Country       Date  Volume
# 0        Venezuela 2016-01-01     1.0
# 32          Turkey 2016-01-01     2.0
# 31        Thailand 2016-01-01     1.0
# 29          Russia 2016-01-01     6.0
# 28          Sweden 2016-01-01     0.0
# ...            ...        ...     ...
# 4253       Belgium 2019-12-24    10.0
# 34151  SouthAfrica 2019-12-24     NaN
# 32727       Russia 2019-12-24     NaN
# 11372      Finland 2019-12-24     NaN
# 44117           UK 2019-12-24     NaN
#
# [47982 rows x 3 columns]

# %%
df.plot(x='Date', y='Volume')

# %%
df['Country'].unique()
# Out:
# array(['Venezuela', 'US', 'India', 'Brazil', 'Malaysia', 'Switzerland',
#        'SouthKorea', 'Indeonesia', 'German', 'France', 'Australia',
#        'NewZealand', 'Netherlands', 'Belgium', 'Ireland', 'Parkistan',
#        'Nigeria', 'UK', 'Philippines', 'Spain', 'Finland', 'Italy',
#        'Canada', 'Mexico', 'SouthAfrica', 'Chili', 'Japan', 'Argentina',
#        'Sweden', 'Russia', 'Columbia', 'Thailand', 'Turkey'], dtype=object)

# %%
df.head()
# Out:
#      Country       Date  Volume
# 0  Venezuela 2016-01-01     1.0
# 1         US 2016-01-01    83.0
# 2      India 2016-01-01     0.0
# 3     Brazil 2016-01-01     1.0
# 4   Malaysia 2016-01-01     1.0

# %%
df.dropna(inplace=True)

# %%
import seaborn as sns
plt.figure(figsize=(20,10))
ax = sns.lineplot(x="Date", y="Volume", hue="Country", 
                     data=df)

# %%
import numpy as np
table = pd.pivot_table(df, values='Volume', index='Date',
                    columns='Country', aggfunc=np.sum)
table.head()
# Out:
# Country     Argentina  Australia  Belgium  ...    UK     US  Venezuela
# Date                                       ...
# 2016-01-01        3.0        1.0      1.0  ...  13.0   83.0        1.0
# 2016-01-02        3.0        4.0      1.0  ...  17.0   68.0        1.0
# 2016-01-03        3.0        2.0      1.0  ...  15.0   99.0        1.0
# 2016-01-04        4.0        1.0      0.0  ...  19.0  177.0        1.0
# 2016-01-05        1.0        3.0      1.0  ...   9.0  129.0        1.0
#
# [5 rows x 33 columns]

# %%
import pandas as pd
import pandas_datareader.data as web

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
plot_cols = list(table.columns)

# 2 axes for 2 subplots

fig, axes = plt.subplots(33,1, figsize=(20, 100), sharex=True)
table[plot_cols].plot(subplots=True, ax=axes)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
#
#
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
#
#
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
#
#
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
#
#
# ...

# %%
import plotly.express as px

# %%
fig = px.line(df, x='Date', y='Volume', )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5c308b94-e541-4bf4-9e4b-5aaf21141552" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5c308b94-e541-4bf4-9e4b-5aaf21141552")) {
#                     Plotly.newPlot(
#                         '5c308b94-e541-4bf4-9e4b-5aaf21141552',
# ...
